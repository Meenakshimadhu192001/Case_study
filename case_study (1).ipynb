# %% [markdown]
# ##Bank Account Manager

# %%
#bank account Details
print("====WELCOME TO INDIAN BANK===")
acc_holder = "Ram"
acc_num = 5678900000
acc_balance = 10000
print("Name:", acc_holder)
print("Account balance:", acc_balance)
# Out:
# ====WELCOME TO INDIAN BANK===
# Name: Ram
# Account balance: 10000

# %%
#Function for depositing money and showing balance
def account(deposit):
   user_deposit = 500
   print(user_deposit)
   total_balance = acc_balance + user_deposit
   print(f"Successfully Credited Rs.",{ user_deposit})
   print("Total balance : ",total_balance)

# %%
#Function for withdrawal money
def withdraw(amount):
   if amount > acc_balance:
        print("Insufficient balance.")
        user_withdrawal = 1500
        total_balance = acc_balance - user_withdrawal
        print(total_balance)

# %% [markdown]
# ##Weather Data Analyze

# %%
#Weather data Analyser
region = "Kerala"
def avg_temperature():
  temperatures = [32, 29, 35, 28, 31]
  print(avg_temperature(temperatures))
  def average_humidity():
    humidities   = [85, 90, 78, 92, 88]
    print(average_humidity(average_humidity))
